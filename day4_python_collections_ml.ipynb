# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaBatraju06/45-Day-Machine-Learning-Journey/blob/main/day4_python_collections_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List:

# %%
numbers=[10,20,30]
numbers.append(40)
numbers.remove(20)
print(numbers)
print(len(numbers))
print(numbers[0])
# Out:
# [10, 30, 40]
# 3
# 10

# %% [markdown]
# Tuple:

# %%
number=(10,20,30)
print(number)
print(number[0])
# Out:
# (10, 20, 30)
# 10

# %% [markdown]
# Set:

# %%
data={"hema","eeshu",30,30,"hema"}
data.add(40)
print(data)
# Out:
# {40, 'eeshu', 'hema', 30}

# %% [markdown]
# Dictionary :

# %%
student={
    "name":"hema",
    "age":"20",
}
print(student)
print(student["name"])
student["branch"]="cse"
print(student)
# Out:
# {'name': 'hema', 'age': '20'}
# hema
# {'name': 'hema', 'age': '20', 'branch': 'cse'}

# %% [markdown]
#                                   practice

# %% [markdown]
# task 1 : find  smallest and largest  number in a list

# %%
number=[ 10,50,100,5,20]
print(max(number))
print(min(number))
# Out:
# 100
# 5

# %% [markdown]
# task 2: find sum of the list

# %%
number=[10,30,5,20,60]
print(sum(number))
# Out:
# 125

# %% [markdown]
# Task 3 : find the count of the elements

# %%
data=[10,20,"hema","puji" ,30,40]
print(len(data))
# Out:
# 6

# %% [markdown]
# Task 4: remove duplicates and print unique values

# %%
number={10,20,30,40,10,20}
unique=set(number)
print(unique)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# project 1:student marks manager  used to find total,avg,highest and lowest

# %%
marks=[50,60,45,65,35]
print("total",sum(marks))
print("Average",sum(marks)/len(marks))
print("highest",max(marks))
print("lowest",min(marks))
# Out:
# total 255
# Average 51.0
# highest 65
# lowest 35

# %% [markdown]
# project 2: contact book using dictionary

# %%
contact={
    "hema":{
        "Name":"Hema",
        "Phone number":"99567332809"
    },
    "pnouji": {
        "name":"puji",
        "ph no":"9767997689"
    }
}
print(contact["hema"])
print(contact["puji"])
# Out:
# {'Name': 'Hema', 'Phone number': '99567332809'}
# {'name': 'puji', 'ph no': '9767997689'}
