# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaBatraju06/45-Day-Machine-Learning-Journey/blob/main/day9_standard_deviation_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variance - spread from the mean

# %%
#mean
import statistics
data=[20,15,10]
statistics.mean(data)
# Out:
# 15

# %%
#variance
statistics.variance(data)
# Out:
# 25

# %% [markdown]
# Standard Deviation - Square root of variance

# %%
# SD
statistics.stdev(data)
# Out:
# 5.0
