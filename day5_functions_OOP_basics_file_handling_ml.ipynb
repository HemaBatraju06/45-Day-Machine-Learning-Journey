# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaBatraju06/45-Day-Machine-Learning-Journey/blob/main/day5_functions_OOP_basics_file_handling_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Function:

# %%
#with function
def welcome():
     print("Welcome to Python")
welcome()
welcome()
welcome()
# Out:
# Welcome to Python
# Welcome to Python
# Welcome to Python

# %%
#without function

print("hello")
print("hello")
print("hello")
# Out:
# hello
# hello
# hello

# %%
# function with parameters

def greet(name):
  print("hello",name)
greet("hema")
greet("pujitha")
# Out:
# hello hema
# hello pujitha

# %%
# function with return

def add(a,b):
    return a+b
print(add(10,20))

# %% [markdown]
# practice programs:

# %%
#print name
def name():
  print("hema")
name()
# Out:
# hema

# %%
# add function
def add(a,b):
  return a+b
print(add(10,20))
# Out:
# 30

# %%
#even odd funcion

def check(num):
  if num%2==0:
    print("even")
  else:
    print("odd")
check(8)
# Out:
# even

# %%
#square

def square(num):
  return num*num
print(square(5))
# Out:
# 25

# %%
# largest number funcion

def largest(a,b):
  if a>b:
    return a
  return b
largest(10,20)
# Out:
# 20

# %% [markdown]
#                           OOP Basics

# %% [markdown]
# class

# %%
class student:
  pass

# %% [markdown]
# creating object:

# %%
class student:
  pass
s1=student #object created

# %% [markdown]
# init method:

# %%
class student:
  def __init__(self,name):
    self.name=name
s1=student("hema")
print(s1.name)
# Out:
# hema

# %% [markdown]
# Practice programs:

# %%
# student class

class student:
  def __init__(self,name,age):
    self.name=name
    self.age=age
s1=student("hema",19)
print(s1.name)
print(s1.age)
# Out:
# hema
# 19

# %%
# car class

class car:
  def __init__(self,brand,model):
    self.brand=brand
    self.model=model
c1=car("audi","a4")
print(c1.brand)
print(c1.model)
# Out:
# audi
# a4

# %% [markdown]
#                  File Handling

# %%
# write file

file=open("file.txt","w")
file.write("hello")
file.close()

# %%
# read file

file=open("file.txt","r")
print(file.read())
file.close()
# Out:
# hello

# %%
#append file

file=open("file.txt","a")
file.write("\npython")
file.close()

# %%
#read file

file=open("file.txt","r")
print(file.read())
file.close()
# Out:
# hellohello
# python

# %% [markdown]
#   Build student notes saver

# %%
class Student:
    def __init__(self,name,note):
        self.name = name
        self.note = note
def save_note(student):
    with open("notes.txt","a") as file:
        file.write(student.name + "\n")
        file.write(student.note + "\n\n")
name = input("Enter Name: ")
note = input("Enter Note: ")
s1 = Student(name,note)
save_note(s1)
print("Note Saved Successfully")
# Out:
# Enter Name: eeshu
# Enter Note: python foundation
# Note Saved Successfully
