# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaBatraju06/45-Day-Machine-Learning-Journey/blob/main/day1_python_basics_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                                                             **Practice**

# %% [markdown]
#      Task1: take name,age,college print them

# %%
name="hema"
age=19
college="RCE"
print(name)
print(age)
print(college)
# Out:
# hema
# 19
# RCE

# %% [markdown]
# task 2: take 2 numbers and peform arithmetic  operaions

# %%
 num1=10
 num2=20
 print("Addition:",num1+num2)
 print("Subtraction:",num1-num2)
 print("Multiplication:",num1*num2)
 print("Division:",num1/num2)
# Out:
# Addition: 30
# Subtraction: -10
# Multiplication: 200
# Division: 0.5

# %% [markdown]
# task 3: take users name

# %%
 name=str(input("Enter your name:"))
 print("Hello",name)
 print("welcome to python")
# Out:
# Enter your name: Hema
# Hello  Hema
# welcome to python

# %% [markdown]
# Task 4: take age ,Output:After 5 years your age will be 25

# %%
age=20
print("After 5 years your age will be",age+5)
# Out:
# After 5 years your age will be 25

# %% [markdown]
#  Task 5: Take marks of 3 subjects and calculae total

# %%
sub1=int(input("Enter the marks of sub1:"))
sub2=int(input("Enter the marks of sub2:"))
sub3=int(input("Enter the marks of sub3:"))
total=sub1+sub2+sub3
print("Total:",total)
# Out:
# Enter the marks of sub1:50
# Enter the marks of sub2:54
# Enter the marks of sub3:45
# Total: 149

# %% [markdown]
#                     Build project 1: calculater

# %%
num1=float(input("Enter the first number:"))
num2=float(input("Enter the second number:"))
print("Addition:",num1+num2)
print("Subtraction:",num1-num2)
print("Multiplication:",num1*num2)
print("Division:",num1/num2)
# Out:
# Enter the first number:5.0
# Enter the second number:3.0
# Addition: 8.0
# Subtraction: 2.0
# Multiplication: 15.0
# Division: 1.6666666666666667

# %% [markdown]
#               Build project 2: Age finder

# %%
birth_year=int(input("Enter your year of birth:"))
current_year=2026
Age=current_year-birth_year
print(" your age is:",Age)
# Out:
# Enter your year of birth:2006
#  your age is: 20

# %% [markdown]
#                       Build project 3: unit converter

# %%
kilometer=float(input("Enter a kilometer:"))
meter=kilometer*1000
print("Meter:",meter)
# Out:
# Enter a kilometer:5.0
# Meter: 5000.0
