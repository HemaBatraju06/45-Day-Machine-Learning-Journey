# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaBatraju06/45-Day-Machine-Learning-Journey/blob/main/day7_probability_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Probability - Measures chance of an event

# %%
# dice

possible_outcome=6
favaourite_outcome = 3

probability=favaourite_outcome/possible_outcome
print(probability)
# Out:
# 0.5

# %% [markdown]
# Conditional probability - Probability after  getting a extra information

# %%
total_students=50
python_and_ml_students=20
ml_students=20

probability_python=python_and_ml_students/total_students
print(probability_python)

probability_ml=ml_students/total_students
print(probability_ml)
# Out:
# 0.4
# 0.4

# %% [markdown]
# Bayes Theorem - update the probability with new information
#
# old_probability + New_information = update_probability

# %% [markdown]
# practice :

# %%
# even numbers in a dice
total =6
even=3   #2,4,6
p_even=even/total
print(p_even)
# Out:
# 0.5

# %%
# Find probability of selecting a Python student.
total_students=50
python_students=20
probability_python=python_students/total_students
print(probability_python)
# Out:
# 0.4

# %%
#Find conditional probability
ml_students=40
python_ml_students=25
p_python_ml_students=(python_ml_students)/(ml_students)
print(p_python_ml_students)
# Out:
# 0.625
