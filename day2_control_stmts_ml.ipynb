# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaBatraju06/45-Day-Machine-Learning-Journey/blob/main/day2_control_stmts_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# if stmt:

# %%
age=20
if age>=18:
  print("eligible to vote")
# Out:
# eligible to vote

# %% [markdown]
# if- else stmt:

# %%
number=int(input(" enter number:"))
if  number>0:
  print("positive number")
else:
  print("negative number")
# Out:
#  enter number:0
# negative number

# %%
age=int(input("enter age:"))
if age>=18:
  print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# enter age:18
# eligible to vote

# %% [markdown]
#  Elif stmt :

# %%
marks=int(input("enter marks:"))
if marks>=90:
  print("grade A")
elif marks>=80:
  print("grade B")
elif marks>=70:
  print("grade C")
else:
  print("fail")
# Out:
# enter marks:52
# fail

# %% [markdown]
# practice:
# task1- check num even or odd

# %%
num=int(input("enter number:"))
if(num%2==0):
  print("even number")
else:
  print("odd number")
# Out:
# enter number:2
# even number

# %% [markdown]
# task2-  find pass or fail for given number

# %%
marks=int(input("enter marks:"))
if marks>=35:
  print("pass")
else:
  print("fail")
# Out:
# enter marks:52
# pass

# %% [markdown]
# task3- take number and find the number is positive,negative or zero using if,else,elif

# %%
number=int(input("enter number:"))
if number>0:
  print("positive number")
elif number<0:
  print("negative number")
else:
  print("zero")
# Out:
# enter number:-5
# negative number

# %% [markdown]
# task4-  temperaure

# %%
temperature=float(input("enter temperature:"))
if temperature>35:
  print("hot")
elif temperature<20:
  print("cold")
elif temperature>=20 and temperature<=35:
  print("normal")
# Out:
# enter temperature:24
# normal

# %% [markdown]
#  build project 1: Large number finder

# %%
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
if num1>num2:
  print("largest number is:",num1)
else:
  print("largest number is:",num2)
# Out:
# enter first number:54
# enter second number:12
# largest number is: 54

# %% [markdown]
# build project : ATM eligibility

# %%
acc_balance=float(input("enter acc balance"))
if acc_balance>=1000.00:
  print("withdrawal allowed")
else:
  print("in sufficient balance")
# Out:
# enter acc balance1500
# withdrawal allowed

# %% [markdown]
#       project 3:vote eligibility

# %%
age=int(input("Enter your age:"))
has_id=input("Do you have an ID card:")
if age>=18 and has_id=="yes":
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age:52
# Do you have an ID card:no
# You are not eligible to vote
